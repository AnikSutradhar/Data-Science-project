# %%
import pandas as pd
import numpy as np
data=pd.read_csv('D:\study\DATA SCIENENCE PROGRAMME\Anik Sutradhar - free_session_information.csv')

# %%
data.columns
# Out:
# Index(['Time Stamp ', 'Name of the candidate ', 'Contact ', 'Email id ',
#        'College name ', 'Brach ', 'People having laptop ',
#        'Souce of communication ', 'Unnamed: 8', 'Unnamed: 9', 'Country '],
#       dtype='object')

# %%
data.drop(['Unnamed: 8', 'Unnamed: 9','Contact ', 'Email id '],axis=1,inplace=True)
data
# Out:
#             Time Stamp   Name of the candidate   \
# 0    8/24/2020 17:01:39  A.S.M. Raquibul Hasan
# 1    8/24/2020 10:08:54                Abdullah
# 2     8/24/2020 9:20:28    Abdullah Bin Murad
# 3    7/28/2020 12:16:30       Abhijoy Mukherjee
# 4    7/10/2020 13:56:14     Abhipreeti Acharjee
# ..                  ...                     ...
# 963  1/22/2021 22:06:24       Ramanish Banerjee
# 964  1/22/2021 22:46:21          Jinia Banerjee
# 965  1/23/2021 10:57:08        Md Safiqul Islam
# 966  1/23/2021 12:27:32     Soumojit Chatterjee
# 967  1/23/2021 17:37:35  Debanjan Bhattacharjee
#
#                                          College name             Brach   \
# 0                     United International University             others
# 1                                                  IIT       Engineering
# 2       Shahjalal University of Science and Technology       Engineering
# 3                                      Asutosh College        Statistics
# ...

# %%
data.isna().sum()
# Out:
# Time Stamp                  20
# Name of the candidate       21
# College name                28
# Brach                       35
# People having laptop        28
# Souce of communication     536
# Country                    492
# dtype: int64

# %%
data.dropna(inplace=True,subset=['Name of the candidate ','College name ', 'Brach ','People having laptop '])
data
# Out:
#             Time Stamp   Name of the candidate   \
# 0    8/24/2020 17:01:39  A.S.M. Raquibul Hasan
# 2     8/24/2020 9:20:28    Abdullah Bin Murad
# 3    7/28/2020 12:16:30       Abhijoy Mukherjee
# 4    7/10/2020 13:56:14     Abhipreeti Acharjee
# 5    7/28/2020 13:14:59    Abhiraj Bhattacharya
# ..                  ...                     ...
# 963  1/22/2021 22:06:24       Ramanish Banerjee
# 964  1/22/2021 22:46:21          Jinia Banerjee
# 965  1/23/2021 10:57:08        Md Safiqul Islam
# 966  1/23/2021 12:27:32     Soumojit Chatterjee
# 967  1/23/2021 17:37:35  Debanjan Bhattacharjee
#
#                                          College name             Brach   \
# 0                     United International University             others
# 2       Shahjalal University of Science and Technology       Engineering
# 3                                      Asutosh College        Statistics
# 4    DEPARTMENT OF PURE MATHEMATICS, UNIVERSITY OF ...  PURE MATHEMATICS
# ...

# %%
data.isna().sum()
# Out:
# Time Stamp                   0
# Name of the candidate        0
# College name                 0
# Brach                        0
# People having laptop         0
# Souce of communication     501
# Country                    466
# dtype: int64

# %%
data['Souce of communication '].fillna(method='ffill',inplace=True)
data
# Out:
#             Time Stamp   Name of the candidate   \
# 0    8/24/2020 17:01:39  A.S.M. Raquibul Hasan
# 2     8/24/2020 9:20:28    Abdullah Bin Murad
# 3    7/28/2020 12:16:30       Abhijoy Mukherjee
# 4    7/10/2020 13:56:14     Abhipreeti Acharjee
# 5    7/28/2020 13:14:59    Abhiraj Bhattacharya
# ..                  ...                     ...
# 963  1/22/2021 22:06:24       Ramanish Banerjee
# 964  1/22/2021 22:46:21          Jinia Banerjee
# 965  1/23/2021 10:57:08        Md Safiqul Islam
# 966  1/23/2021 12:27:32     Soumojit Chatterjee
# 967  1/23/2021 17:37:35  Debanjan Bhattacharjee
#
#                                          College name             Brach   \
# 0                     United International University             others
# 2       Shahjalal University of Science and Technology       Engineering
# 3                                      Asutosh College        Statistics
# 4    DEPARTMENT OF PURE MATHEMATICS, UNIVERSITY OF ...  PURE MATHEMATICS
# ...

# %%
data['Souce of communication '].fillna(method='ffill',inplace=True)
data
# Out:
#             Time Stamp   Name of the candidate   \
# 0    8/24/2020 17:01:39  A.S.M. Raquibul Hasan
# 2     8/24/2020 9:20:28    Abdullah Bin Murad
# 3    7/28/2020 12:16:30       Abhijoy Mukherjee
# 4    7/10/2020 13:56:14     Abhipreeti Acharjee
# 5    7/28/2020 13:14:59    Abhiraj Bhattacharya
# ..                  ...                     ...
# 963  1/22/2021 22:06:24       Ramanish Banerjee
# 964  1/22/2021 22:46:21          Jinia Banerjee
# 965  1/23/2021 10:57:08        Md Safiqul Islam
# 966  1/23/2021 12:27:32     Soumojit Chatterjee
# 967  1/23/2021 17:37:35  Debanjan Bhattacharjee
#
#                                          College name             Brach   \
# 0                     United International University             others
# 2       Shahjalal University of Science and Technology       Engineering
# 3                                      Asutosh College        Statistics
# 4    DEPARTMENT OF PURE MATHEMATICS, UNIVERSITY OF ...  PURE MATHEMATICS
# ...

# %%
data.isna().sum()
# Out:
# Time Stamp                   0
# Name of the candidate        0
# College name                 0
# Brach                        0
# People having laptop         0
# Souce of communication       0
# Country                    466
# dtype: int64

# %%
data['Country '].fillna(value=0,inplace=True)
data
# Out:
#             Time Stamp   Name of the candidate   \
# 0    8/24/2020 17:01:39  A.S.M. Raquibul Hasan
# 2     8/24/2020 9:20:28    Abdullah Bin Murad
# 3    7/28/2020 12:16:30       Abhijoy Mukherjee
# 4    7/10/2020 13:56:14     Abhipreeti Acharjee
# 5    7/28/2020 13:14:59    Abhiraj Bhattacharya
# ..                  ...                     ...
# 963  1/22/2021 22:06:24       Ramanish Banerjee
# 964  1/22/2021 22:46:21          Jinia Banerjee
# 965  1/23/2021 10:57:08        Md Safiqul Islam
# 966  1/23/2021 12:27:32     Soumojit Chatterjee
# 967  1/23/2021 17:37:35  Debanjan Bhattacharjee
#
#                                          College name             Brach   \
# 0                     United International University             others
# 2       Shahjalal University of Science and Technology       Engineering
# 3                                      Asutosh College        Statistics
# 4    DEPARTMENT OF PURE MATHEMATICS, UNIVERSITY OF ...  PURE MATHEMATICS
# ...

# %%
data.isna().sum()
# Out:
# Time Stamp                 0
# Name of the candidate      0
# College name               0
# Brach                      0
# People having laptop       0
# Souce of communication     0
# Country                    0
# dtype: int64

# %%
data.to_csv('free_session.csv')
